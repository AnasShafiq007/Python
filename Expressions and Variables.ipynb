# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Hafiz Anas</b>

# %% [markdown]
# Data Scientist

# %% [markdown]
# <i>I am interested in data science because I would love to contribute towards affordable and quality healthcare in the future</i>

# %% [markdown]
# <h3>The below should print 'Hello World'</h3>

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
#     ---You miss 100% of the shots you don't take

# %% [markdown]
# https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedLti/lJFub/obtain-an-ibm-cloud-feature-code

# %% [markdown]
# ---

# %% [markdown]
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
